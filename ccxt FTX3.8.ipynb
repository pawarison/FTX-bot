# %%
import os
import ccxt
import configparser
import vectorbt as vbt
from datetime import datetime
import pytz
import json
import numpy as np
import talib as ta
import pandas as pd
import schedule
import time
import warnings
import requests
import decimal
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Global configuration

# %%
config = configparser.ConfigParser()
config.read('key.ini')
# --------------------------------------------------
robot_name = 'ActionZone'
robot_api_key = config['key']['apikey'] 
robot_secret_key = config['key']['secretkey']
robot_symbol = 'BTC-PERP' # trade symbol
robot_timeframe = '1m' # only support timeframe: 1m, 3m, 5m, 15m, 1h
robot_max_candles = 100 # total candles to be loaded from exchange, max is 1,000
robot_riskpertrade = 0.0001 # 1%
robot_position_size_limit = 1 # max position size to allow to trade
robot_leverage= 20
#conf_max_retry = 10 # max retry to get data

# --------------------------------------------------
exchange = ccxt.ftx({
    'apiKey' : robot_api_key ,
    'secret' : robot_secret_key ,
    'enableRateLimit': True,
    'option' : {'defaultType' : 'future', 'adjustForTimeDifference': True}
})
exchange.headers = {
    'FTX-SUBACCOUNT': 'testAPI',
}

log_history = 'log_history.csv'
log_ontrade = 'log_ontrade.csv'
# log_debug = Debug_log.txt'

response = exchange.private_post_account_leverage({'leverage': robot_leverage,}) 
print(exchange.fetchStatus())
# Out:
# {'status': 'ok', 'updated': None, 'eta': None, 'url': None}

# %% [markdown]
# ####  ยังไม่ได้ทำ Error log

# %%
#----------------------------
# Utility Function
#----------------------------
def get_time():    
    now = datetime.now()
    formatted_date = now.strftime("%Y/%m/%d %H:%M:%S") # แก้ Format
    return formatted_date

def get_wallet():
    try:
        wallet = exchange.privateGetWalletBalances()['result']
        return wallet
    except:
        return None

def get_cash():
    try:
        wallet = get_wallet()
        for t in wallet:
            if t['coin'] in  ['USD']:
                cash = float(t['availableWithoutBorrow'])
        return cash
    except:
        return None
    
def get_position(symbols): 
    try:
        res = exchange.fetchPositions()
        for sym in res:
            if sym['info']['future']==symbols:
                f_pos = sym['info']
        return f_pos
    except Exception as e:
        log(str(e),logname)
        return None 
    
def get_price_digit(symbol): # นับ digit จาก fetch ticker ล่าสุด
    try:
        res =exchange.fetch_ticker(symbol)# ['info']['minProvideSize']
        price_step = float(res['info']['priceIncrement'])
        str_digit = str(price_step)
        count_digit = len(str_digit.split('.')[1])
        return count_digit
    except :
        pass
    
def get_size_digit(symbol): # นับ digit จาก fetch ticker ล่าสุด
    try:
        res =exchange.fetch_ticker(symbol)# ['info']['minProvideSize']
        size_step = float(res['info']['sizeIncrement'])
        last_price = float(res['info']['last'])
        min_provide = size_step * last_price
        str_digit = str(size_step)
        count_digit = len(str_digit.split('.')[1])

        return count_digit
    except Exception as e :
        log(str(e))
 
def get_minimum_size(symbol): ##จะไม่ได้ต้องเซ็ต fetch minimum จาก exchange กัน error
    res = exchange.fetch_ticker(symbol)['info']#['sizeIncrement']
    minimum_size = float(res['sizeIncrement'])
    last_bid = float(res['bid'])
    min_value =minimum_size * last_bid
    return float(minimum_size)

def check_positions():
    res = exchange.private_get_positions()['result']   
    for symbol in res:
        if symbol['future'] in robot_symbol:
            netsize = float(symbol['netSize'])
            if netsize > 0:
                positions = 1 # Have Long Positions
            elif netsize < 0:
                positions = -1 # Have Short Positions
            else :
                positions = 0 # No Positions
            return positions  
        

def fetch_data(symbols = robot_symbol, timeframe = robot_timeframe, limit = robot_max_candles):
    try:        
        bars = exchange.fetch_ohlcv(symbols, timeframe, limit = limit)
        df = pd.DataFrame(bars[:-1], columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
        return df
    except :
        print('LOAD DATA ERROR ')
        return pd.DataFrame()
        
    
def is_new_bar(prev_bar_time, cur_bar_time):
    if cur_bar_time > prev_bar_time:
        return True
    else:
        return False  
        
def load_last_ts_entry(last_side):
    ''' Fetch last Timestamp filter by side , symbols '''
    all_ts = []
    res_trades = exchange.fetch_my_trades(robot_symbol)
    for i in res_trades:
        if i['side'] == last_side:
            all_ts.append((i['timestamp']))
            last_ts =min(all_ts)
            return last_ts  
        
robot_min_size = get_minimum_size(robot_symbol)

# %%
def create_open_market_order(symbols:str, side:str, size:float, params={}):  ### Custom param
    try:
        orderInfo = exchange.create_order(robot_symbol, 'market',side , size, params = params)["info"]
        orderID = orderInfo["id"]
        entry_ts = exchange.parse8601(orderInfo['createdAt'])
        print(f'Time sleep To Fetch Trades {entry_ts}') 
        time.sleep(5)
        res_trades = exchange.fetch_my_trades(symbols, since=int(entry_ts))
        if res_trades != []:
            entry_df_ts  = pd.DataFrame(res_trades)
            entry_df  = entry_df_ts.groupby('symbol').agg({'timestamp':'last','side':'last','price':'mean','amount':'sum','cost':'sum'}).reset_index()
            return entry_df
        else:
            print('Cannot Fetch last Trades')
            return pd.DataFrame()
    except ccxt.InvalidOrder as e:
        pass
    except ccxt.NetworkError as e:
        pass
    except ccxt.ExchangeError as e:
        pass
    except ccxt.InsufficientFunds as e:
        pass
    
def close_positions(symbols=robot_symbol):    
    close_df = pd.DataFrame()
    netsize = float(get_position(symbols)['netSize'])
    if netsize > 0:
        close_df = create_open_market_order(symbols, side='sell', size=abs(netsize), params={'conditionalOrdersOnly':True}) 
        if (not close_df.empty):
            close_df = close_df.add_suffix('_exit')     
    elif netsize < 0:  
        close_df = create_open_market_order(symbols, side='buy', size=abs(netsize), params={'conditionalOrdersOnly':True})
        close_df = close_df.add_suffix('_exit')
    else :
        print('No positions to close')
    return close_df

# %%
def log(msg,TXTFILE):
    timestamp = get_time()
    s = f"[{timestamp}] {msg}"
    print(s)
    print('#' * 50)
    try:
        f = open(TXTFILE, "a")
        f.write(s + "\n")
        f.close()
    except:
        pass

#----------------------------
# For ontrade log
#----------------------------
def read_log_ontrade():
    ''' Read Csv ontrade Files'''
    try:
        df =pd.read_csv(log_ontrade, usecols=['symbol','timestamp','side','price','amount','cost','stop_loss','take_profit'])
        print('Read Trade Files ')
        return df
    except :
        print('Create ontrade Files')
        df =pd.DataFrame(columns=['symbol','timestamp','side','price','amount','cost','stop_loss','take_profit'])
        return df
    
def reset_log_ontrade():
    ''' Reset DataFrame and save to ontrade Files'''
    df = pd.DataFrame(columns=['symbol','timestamp','side','price','amount','cost','stop_loss','take_profit'])
    df.to_csv(log_ontrade)
    return df

def load_log_ontrade(df,entry_df):
    ''' Load Position and calculation SL,tp if Not HoldPostion Reset Trades Files '''
    last_position = check_positions()
    print(last_position)
    if  (not entry_df.empty):
        if last_position == 1:
            # Fetch trades
            f_pos = get_position(robot_symbol)

            entry_df.symbol =  [robot_symbol]
            entry_df['timestamp'] = [int(load_last_ts_entry(f_pos['side'])/1000)]#datetime.fromtimestamp(int(load_last_ts_entry(last_side)/1000)) #int(df['timestamp'].iloc[-1].timestamp())
            entry_df['price'] =  [float(f_pos['recentAverageOpenPrice'])  ]
            entry_df['side'] = [f_pos['side']] 
            entry_df['amount'] =  [float(f_pos['size'])]
            entry_df['cost'] = [float(f_pos['size']) * float(f_pos['recentAverageOpenPrice'])]
            entry_df['stop_loss'] = [float(f_pos['recentAverageOpenPrice']) - Cal_SLdistance(df) ] 
            entry_df['take_profit'] = [0.0]
        elif last_position == -1:
            f_pos = get_position(robot_symbol)
            entry_df.symbol =  [robot_symbol]
            entry_df['timestamp'] = [int(load_last_ts_entry(f_pos['side'])/1000)]#datetime.fromtimestamp(int(load_last_ts_entry(last_side)/1000)) #int(df['timestamp'].iloc[-1].timestamp())
            entry_df['price'] =  [float(f_pos['recentAverageOpenPrice'])  ]
            entry_df['side'] = [f_pos['side']] 
            entry_df['amount'] =  [float(f_pos['size'])]
            entry_df['cost'] = [float(f_pos['size']) * float(f_pos['recentAverageOpenPrice'])]
            entry_df['stop_loss'] = [float(f_pos['recentAverageOpenPrice']) + Cal_SLdistance(df)] 
            entry_df['take_profit'] = [0.0]

        else: # Postion == 0 if not have position reset_trade_log
            entry_df = reset_log_ontrade()
    else:
        if last_position == 1:
            latest_log = {}
            f_pos = get_position(robot_symbol)
            latest_log['symbol'] =  f_pos['future']
            latest_log['entry_time'] = df['timestamp'].iloc[-1]
            latest_log['entry_price'] =  float(f_pos['recentAverageOpenPrice'])  
            latest_log['position_side'] = f_pos['side'] 
            latest_log['position_amount'] =  float(f_pos['size'])
            latest_log['stop_loss'] = float(f_pos['recentAverageOpenPrice']) - Cal_SLdistance(df)  
            latest_log['take_profit'] = 0.0
            entry_df = pd.DataFrame([latest_log])

        elif last_position == -1:
            latest_log = {}
            f_pos = get_position(robot_symbol)
            latest_log['symbol'] =  f_pos['future']
            latest_log['entry_time'] = df['timestamp'].iloc[-1]
            latest_log['entry_price'] =  float(f_pos['recentAverageOpenPrice'])  
            latest_log['position_side'] = f_pos['side'] 
            latest_log['position_amount'] =  float(f_pos['size'])
            latest_log['stop_loss'] = float(f_pos['recentAverageOpenPrice']) + Cal_SLdistance(df)  
            latest_log['take_profit'] = 0.0
            entry_df = pd.DataFrame([latest_log])
        else: 
            entry_df = reset_log_ontrade()


    return entry_df   

#----------------------------
# For history log
#----------------------------
def close_trades(entry_df, exit_df):
    if not entry_df.empty:
        trades_df = pd.concat([entry_df,exit_df],axis=1)
        side_= trades_df['side'][0]
        if side_ =='buy':
            trades_df['diff_price'] = trades_df['price_exit'] - trades_df['price'] 
            trades_df['pnl'] = trades_df['cost_exit'] - trades_df['cost'] 
            trades_df =trades_df.reset_index()
        else:
            trades_df['diff_price'] =  trades_df['price'] -trades_df['price_exit']
            trades_df['pnl'] =  trades_df['cost'] - trades_df['cost_exit'] 
            trades_df =trades_df.reset_index()       
    else:
        trades_df =pd.DataFrame()
    return trades_df

def save_trades(all_trades, trades_df):
    ''' Save Trades Record to log_history'''
    if not trades_df.empty:
        all_trades = all_trades.append(trades_df).set_index('symbol')
        all_trades.to_csv(log_history)
        print('RECORD TRADES')
    else:
        print('Cannot Get Trades Details')
        pass
    
def read_log_history():
    ''' Read Csv log_history Files'''
    try:
        df= pd.read_csv(log_history)
        print('---DataBase Loaded---')

    except:
        df= pd.DataFrame(columns=['symbol','timestamp','side','price','amount','cost'])
        df.to_csv(log_history, index=False)
        print("---DataBase Created---")
    return df

# %%
#----------------------------
# Strategy Zone
#----------------------------
def Cal_Size(df, robot_riskpertrade = robot_riskpertrade):
    cash = get_cash()
    size= 0.0
    if cash != None:
        riskpertrade = robot_riskpertrade * cash
        size = (riskpertrade / Cal_SLdistance(df)) 
        if size > robot_position_size_limit:
            size = robot_position_size_limit
        elif size < robot_min_size:
            size = robot_min_size    
    return round(size, get_size_digit(robot_symbol))

def Cal_SLdistance(df, vol_multiply = 1):
    vol = ta.STDDEV(df.close,30).ewm(alpha=0.96).mean()
    sl_distance = vol * vol_multiply
    return sl_distance.iloc[-1]

def Cal_TPdistance(df, vol_multiply = 1.2):
    vol = ta.STDDEV(df.close,30).ewm(alpha=0.96).mean()
    tp_distance = vol * vol_multiply
    return tp_distance.iloc[-1]

def strategy(df):    
    if (not df.empty) :
        df['ema1'] = ta.EMA(df.close, 12)
        df['ema2'] = ta.EMA(df.close, 26)
        
        df['LongEntries'] = (df['ema1'] > df['ema2']) & (df['ema1'].shift(1) < df['ema2']) & (df.close > df['ema1'])
        df['LongExit'] = df.close < df['ema2']   
        df['ShortEntries'] = (df['ema1'] < df['ema2']) & (df['ema1'].shift(1) > df['ema2']) & (df.close < df['ema1'])
        df['ShortExit'] = df.close > df['ema2'] 
        return df
    
    else:
        print('Cant Fetch Data' )
        return df

# %%
def trading():
    global prev_bar
    global exit_df
    global all_trades
    
    now_dt =get_time()
    
    if prev_bar != 0:
        prev_bar_str = datetime.utcfromtimestamp(int(prev_bar/1000))
    else:
        prev_bar_str= []
        
    df_raw = fetch_data()
    df = strategy(df_raw) # add fetchingdata to strategy

    print(f'RUN BOT  @ {now_dt} ')
    if  not df.empty:
        LongEntries = df['LongEntries'].iloc[-1] #[last_row_index]
        LongExit = df['LongExit'].iloc[-1]   
        ShortEntries = df['ShortEntries'].iloc[-1]
        ShortExit = df['ShortExit'].iloc[-1]
        size = Cal_Size(df)
        
        print('Long : ',LongEntries,LongExit )    
        print('SHORT: ',ShortEntries,ShortExit )
        
        cur_bar_str =   df.timestamp.iloc[-1]
        cur_bar_time = int(cur_bar_str.timestamp()*1000) #
        new_bar_cond = is_new_bar(prev_bar,cur_bar_time)
        last_position = check_positions()
        last_price = df['close'].iloc[-1]
        
        entry_df = read_log_ontrade() 
        
        if not entry_df.empty  :
            print(f" Latest Position Holding : {entry_df}")     
            print('----------------------------------------')
        else:
            print(f" Position {robot_symbol} Position Side : {last_position}")
        
        if (prev_bar != cur_bar_time) :
            print('NEW BAR')
            if last_position == 0: 
                if LongEntries == True:    
                    entry_df = create_open_market_order(robot_symbol, 'buy', size = size)
                    entry_df = load_log_ontrade(df, entry_df) 
                    time.sleep(2)
                    entry_df.to_csv(log_ontrade)
                    
                    print("------ Open Long ------")

                elif ShortEntries == True: 
                    entry_df = create_open_market_order(robot_symbol,'sell',size=size)
                    entry_df = load_log_ontrade(df,entry_df) # WITH SL ,TP
                    entry_df.to_csv(log_ontrade)
                    time.sleep(2)

                    print("------ Open Short ------")

                else :
                    print('No Positions and Signals')
                    entry_df = reset_log_ontrade()

    
            elif last_position == 1:
                if LongExit == True :
                    exit_df = close_positions(robot_symbol)
                    trades_df = close_trades(entry_df,exit_df)
                    save_trades(all_trades,trades_df)
                    entry_df = load_log_ontrade(df,entry_df) # Close Reset
                    time.sleep(2)
                    entry_df.to_csv(log_ontrade)
                    print("------ Exit Long ------")

                elif  (not entry_df['symbol'].empty):
                    if (entry_df['take_profit'][0] != 0.0) & (last_price >= entry_df['take_profit'][0]):
                        exit_df = close_positions(robot_symbol)
                        trades_df = close_trades(entry_df,exit_df)
                        save_trades(all_trades,trades_df)
                        entry_df = load_log_ontrade(df,entry_df) # Close Reset
                        time.sleep(2)
                        entry_df.to_csv(log_ontrade)
                        print('TAKE PROFIT Long')
                    else:
                        print('Not Set TP')
                    
                elif (not entry_df['symbol'].empty) :
                    if (entry_df['stop_loss'][0] != 0.0)& (last_price <= entry_df['stop_loss'][0]) :
                        exit_df =close_positions(robot_symbol)
                        trades_df =close_trades(entry_df,exit_df)
                        save_trades(all_trades,trades_df)
                        entry_df = load_log_ontrade(df,entry_df) # Close Reset
                        time.sleep(2)
                        entry_df.to_csv(log_ontrade)
                        print('STOPLOSS Long')
                    else:
                        print('NOT SET SL')
                        
                elif ShortEntries == True: # Reverse Signal
                    exit_df = close_positions(robot_symbol)
                    trades_df = close_trades(entry_df,exit_df)
                    save_trades(all_trades, trades_df)
                    entry_df = load_log_ontrade(df, entry_df) # Close Reset
                    entry_df = create_open_market_order(robot_symbol, 'sell', size=size)
                    entry_df = load_log_ontrade(df,entry_df) # Calculation tp ,sl to entry_dataframe
                    time.sleep(2)
                    entry_df.to_csv(log_ontrade)
                    print("------ Open Short ------")
                    
                else:
                    print('Have Long Positions, No signal')
                    if entry_df['symbol'].empty or entry_df['price'].empty: # have position but lastest_log not calculation 
                        entry_df = load_log_ontrade(df,entry_df) # Close Reset
                        time.sleep(2)
                        entry_df.to_csv(log_ontrade)
                        print('NEW ', entry_df)
                    else:
                        print('Holding ', entry_df)
                                                
                        
            elif last_position== -1: # Have Short Positions 

                if ShortExit == True :
                    exit_df = close_positions(robot_symbol)
                    trades_df = close_trades(entry_df,exit_df)
                    save_trades(all_trades,trades_df)     
                    entry_df = load_log_ontrade(df,entry_df) # Close Reset
                    time.sleep(2)
                    entry_df.to_csv(log_ontrade)
                    print("------ Exit Short ------")

                elif (not entry_df['symbol'].empty):
                    if (entry_df['take_profit'][0] != 0.0)& (last_price <= entry_df['take_profit'][0]):

                        exit_df = close_positions(robot_symbol)
                        # เพิ่ม
                        trades_df = close_trades(entry_df,exit_df)
                        save_trades(all_trades,trades_df)
                        entry_df = load_log_ontrade(df,entry_df) # Close Reset
                        time.sleep(2)
                        entry_df.to_csv(log_ontrade) 
                        print('TAKE PROFIT Short')
                    else:
                        print('Not Set TP')
                        
                elif  (not entry_df['symbol'].empty) :
                    if (entry_df['stop_loss'][0] != 0.0)& (last_price >= entry_df['stop_loss'][0]):

                        exit_df =close_positions(robot_symbol)
                        # เพิ่ม
                        trades_df =close_trades(entry_df,exit_df)
                        save_trades(all_trades,trades_df)
                        entry_df = load_log_ontrade(df,entry_df) # Close Reset
                        time.sleep(2)
                        entry_df.to_csv(log_ontrade)
                        print('STOPLOSS Short')                                       
                    else:
                        print('Not Set SL' )
                        
                elif LongEntries == True: # Reverse Signal
                    exit_df = close_positions(robot_symbol)
                    trades_df = close_trades(entry_df,exit_df)
                    save_trades(all_trades,trades_df)
                    entry_df = load_log_ontrade(df,entry_df) # Close Reset
                    entry_df = create_open_market_order(robot_symbol,'sell',size=size)
                    entry_df = load_log_ontrade(df,entry_df) # Close Reset
                    time.sleep(2)
                    entry_df.to_csv(log_ontrade)
                    print("------ Open Long ------")

                else:
                    print('Have Short Positions, No signal')
                    if entry_df['symbol'].empty or  entry_df['price'].empty: # have position but lastest_log not calculation 
                        entry_df = load_log_ontrade(df,entry_df) # Close Reset
                        time.sleep(2)
                        entry_df.to_csv(log_ontrade)

                        print('NEW ',entry_df)
                    else:
                        print('Holding' ,entry_df)

        else:
            print('SAMEBAR')

        prev_bar = cur_bar_time
        print('-'*50)
        
    else:
        print('Can Not get DataFrame')
        pass

# %%
from IPython.display import clear_output
count = 0
prev_bar = 0
exit_df = pd.DataFrame()
all_trades = read_log_ontrade()
print(f'{robot_symbol} BOT, Time Frame {robot_timeframe}, RPT {robot_riskpertrade*100:.2f}, MAX LEVERAGE {robot_leverage}')
print('-'*50)
while True:
    trading()
    count += 1
    time.sleep(30)
    if count == 1000:
        count = 0
        clear_output(wait=True)
# Out:
# Read Trade Files
# BTC-PERP BOT, Time Frame 1m, RPT 0.01, MAX LEVERAGE 20
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:14:21
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:14:52
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:15:24
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:15:55
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:16:27
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:16:58
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:17:29
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:18:00
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:18:32
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:19:03
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:19:34
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:20:06
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:20:37
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:21:08
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:21:39
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:22:11
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:22:42
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:23:14
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:23:45
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:24:16
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:24:47
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:25:19
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:25:50
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:26:21
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:26:52
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:27:23
# Long :  False True
# SHORT:  True False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# Time sleep To Fetch Trades 1648225644698
# -1
# ------ Open Short ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:28:03
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount   cost     stop_loss  \
# 0  BTC-PERP  1648084464  sell  44420.0  0.0001  4.442  44519.223562
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Time sleep To Fetch Trades 1648225685204
# RECORD TRADES
# 0
# ------ Exit Short ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:28:44
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:29:15
# Long :  True False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# Time sleep To Fetch Trades 1648225757084
# 1
# ------ Open Long ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:29:55
# Long :  True False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648084564  buy  44442.0  0.0001  4.4442  44347.88394
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:30:26
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648084564  buy  44442.0  0.0001  4.4442  44347.88394
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:30:58
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648084564  buy  44442.0  0.0001  4.4442  44347.88394
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:31:29
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648084564  buy  44442.0  0.0001  4.4442  44347.88394
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Time sleep To Fetch Trades 1648225891197
# RECORD TRADES
# 0
# ------ Exit Long ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:32:09
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:32:40
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:33:11
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:33:42
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:34:14
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:34:45
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:35:17
# Long :  True False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# Time sleep To Fetch Trades 1648226118686
# 1
# ------ Open Long ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:35:57
# Long :  True False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648085116  buy  44464.0  0.0001  4.4464  44389.10331
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:36:28
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648085116  buy  44464.0  0.0001  4.4464  44389.10331
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:36:59
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648085116  buy  44464.0  0.0001  4.4464  44389.10331
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:37:31
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648085116  buy  44464.0  0.0001  4.4464  44389.10331
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:38:02
# Long :  False True
# SHORT:  True False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp side    price  amount    cost    stop_loss  \
# 0  BTC-PERP  1648085116  buy  44464.0  0.0001  4.4464  44389.10331
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Time sleep To Fetch Trades 1648226284074
# RECORD TRADES
# 0
# ------ Exit Long ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:38:41
# Long :  False True
# SHORT:  True False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:39:13
# Long :  False True
# SHORT:  True False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# Time sleep To Fetch Trades 1648226354481
# -1
# ------ Open Short ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:39:52
# Long :  False True
# SHORT:  True False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:40:24
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:40:55
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:41:26
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:41:58
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:42:29
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:43:01
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:43:32
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:44:03
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:44:35
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:45:06
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:45:37
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:46:08
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:46:40
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:47:11
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:47:43
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:48:14
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:48:45
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:49:16
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:49:48
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:50:19
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:50:50
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:51:21
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:51:53
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:52:25
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:52:57
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:53:28
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:53:59
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:54:30
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:55:02
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:55:33
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:56:04
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:56:36
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:57:07
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:57:38
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:58:09
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:58:41
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:59:12
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/25 23:59:43
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:00:14
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:00:46
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:01:17
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:01:48
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:02:19
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:02:51
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:03:22
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Not Set TP
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:03:53
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:04:25
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Latest Position Holding :      symbol   timestamp  side    price  amount    cost     stop_loss  \
# 0  BTC-PERP  1648193360  sell  44393.0  0.0001  4.4393  44459.060128
#
#    take_profit
# 0          0.0
# ----------------------------------------
# NEW BAR
# Time sleep To Fetch Trades 1648227867243
# RECORD TRADES
# 0
# ------ Exit Short ------
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:05:05
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:05:36
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:06:07
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:06:38
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:07:09
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:07:41
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:08:12
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:08:43
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:09:15
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:09:46
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:10:17
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:10:48
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:11:20
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:11:51
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:12:22
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:12:54
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:13:25
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:13:56
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:14:27
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:14:58
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:15:30
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:16:01
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# SAMEBAR
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:16:32
# Long :  False True
# SHORT:  False False
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
# RUN BOT  @ 2022/03/26 00:17:04
# Long :  False False
# SHORT:  False True
# Read Trade Files
#  Position BTC-PERP Position Side : 0
# NEW BAR
# No Positions and Signals
# --------------------------------------------------
